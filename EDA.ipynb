# %%
import pandas as pd
from matplotlib import pyplot as plt
% matplotlib inline

# %%
import edautils
edautils.set_plot()

# %% [markdown]
# # Data from one building, ranging from 1st of January 2016 to the end of October 2016
# The records are Watt per minute of the active power of 6 appliances and the aggregate (total power).

# %%
df = pd.read_csv('data_59_all.csv')
df['Datetime'] = pd.to_datetime(df.Datetime)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Datetime</th>
#       <th>Aggregate</th>
#       <th>Air Conditioner</th>
#       <th>Spin Dryer</th>
#       <th>Electric Furnace</th>
#       <th>Oven</th>
#       <th>Electric Swimming Pool Heater</th>
#       <th>Fridge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2016-01-02 12:00:00</td>
#       <td>3794.0</td>
#       <td>2489.0</td>
#       <td>0.0</td>
#       <td>181.0</td>
#       <td>0.0</td>
#       <td>13.0</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
# ...

# %% [markdown]
# # Distribution of the Aggregate during the year

# %%
edautils.plot_measure_hist(df,'Aggregate')

# %% [markdown]
# # Example Aggregate (18 February 2016)

# %%
edautils.plot_daily_values(df,'Datetime','Aggregate',2500,10000,2,18)

# %% [markdown]
# # Distribution of the Fridge active power during the year
# The graph outline the choice of 11 Watt/minute as the threshold for the state of the fridge

# %%
edautils.plot_measure_hist(df,'Fridge')

# %% [markdown]
# # Distribution of the Air Conditioner and Electric Furnace

# %%
edautils.plot_measure_hist(df,'Air Conditioner')

# %%
edautils.plot_measure_hist(df,'Electric Furnace')

# %%
df[df['Electric Furnace']>1000]['Electric Furnace'].count()
# Out:
# 228

# %%
df[df['Electric Furnace']>1000]['Electric Furnace'].max()
# Out:
# 9380.0

# %%
plt.suptitle('Electric Furnace Distribution'+ '\n' + 'values over 1000 kW')
plt.ylabel('kW')
df[df['Electric Furnace']>1000]['Electric Furnace'].hist()

# %% [markdown]
# # Aggregate active power compared with three different appliances

# %%
edautils.compare_measure_and_appliance_activation(df,'Datetime',
                                                     'Aggregate',
                                                     'Electric Furnace',1000)

# %%
edautils.compare_measure_and_appliance_activation(df,'Datetime',
                                                     'Aggregate',
                                                     'Air Conditioner',2400)

# %%
edautils.compare_measure_and_appliance_activation(df,'Datetime','Aggregate','Fridge',11)

# %% [markdown]
# # Appliance peak and signatures

# %%
edautils.plot_daily_values(df,'Datetime','Air Conditioner',2400,4000,6,18)

# %%
edautils.plot_hour_series(df,'Datetime','Air Conditioner',2400,4000,6,18,20,22)

# %%
edautils.plot_daily_values(df,'Datetime','Electric Furnace',1000,10000,1,2)

# %%
edautils.plot_hour_series(df,'Datetime','Electric Furnace',1000,10000,1,2,18,21)

# %%
edautils.plot_daily_values(df,'Datetime','Fridge',11,24,3,7)

# %%
edautils.plot_hour_series(df,'Datetime','Fridge',11,24,3,7,18,21)

# %%
edautils.plot_daily_values(df,'Datetime','Fridge',11,24,5,31)

# %%
edautils.plot_hour_series(df,'Datetime','Fridge',11,24,5,31,18,19)
